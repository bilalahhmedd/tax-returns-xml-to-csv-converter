# %%
import pandas as pd
import xml.etree.ElementTree as ET

# %%
tree = ET.parse('../data/2024/xml/202303569339300005_public.xml')
root = tree.getroot()

# %%
root
# Out:
# <Element '{http://www.irs.gov/efile}Return' at 0x7fe74abee900>

# %%
for data_item in root.findall('.//'):
    data_dict = {}
    # print(data_item)

# %% [markdown]
# #### explore csv file

# %%
# reference_df=pd.read_excel("../22eoextract990.xlsx")

# %%
sample_df = pd.read_excel("../data/2022/sample.xlsx")

# %%
sample_df.columns
# Out:
# Index(['efile', 'EIN', 'tax_pd', 'subseccd', 's501c3or4947a1cd', 'schdbind',
#        'politicalactvtscd', 'lbbyingactvtscd', 'subjto6033cd',
#        'dnradvisedfundscd',
#        ...
#        'exceeds1pct509', 'subtotpub509', 'pubsupplesub509',
#        'samepubsuppsubtot509', 'grsinc509', 'unreltxincls511tx509',
#        'subtotsuppinc509', 'netincunrelatd509', 'othrinc509', 'totsupp509'],
#       dtype='object', length=246)

# %%
for col in sample_df.columns:
    print(col)
# Out:
# efile
# EIN
# tax_pd
# subseccd
# s501c3or4947a1cd
# schdbind
# politicalactvtscd
# lbbyingactvtscd
# subjto6033cd
# dnradvisedfundscd
# prptyintrcvdcd
# maintwrkofartcd
# crcounselingqstncd
# hldassetsintermpermcd
# rptlndbldgeqptcd
# rptinvstothsecd
# rptinvstprgrelcd
# rptothasstcd
# rptothliabcd
# sepcnsldtfinstmtcd
# sepindaudfinstmtcd
# inclinfinstmtcd
# operateschools170cd
# frgnofficecd
# frgnrevexpnscd
# frgngrntscd
# frgnaggragrntscd
# rptprofndrsngfeescd
# rptincfnndrsngcd
# rptincgamingcd
# operatehosptlcd
# hospaudfinstmtcd
# rptgrntstogovtcd
# rptgrntstoindvcd
# rptyestocompnstncd
# txexmptbndcd
# invstproceedscd
# maintescrwaccntcd
# actonbehalfcd
# engageexcessbnftcd
# awarexcessbnftcd
# loantofficercd
# grantoofficercd
# dirbusnreltdcd
# fmlybusnreltdcd
# servasofficercd
# recvnoncashcd
# recvartcd
# ceaseoperationscd
# sellorexchcd
# ownsepentcd
# reltdorgcd
# intincntrlcd
# orgtrnsfrcd
# conduct5percentcd
# compltschocd
# f1096cnt
# fw2gcnt
# wthldngrulescd
# ...
